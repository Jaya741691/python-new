# %%
def fun(x,y):
    print(x,y)
    return x+y
print(fun(10,20))
# Out:
# 10 20
# 30

# %%
def great(a,b):
    if a>b:
        return a
    else:
        return b

print(great(66,88))
# Out:
# 88

# %%
k=list(map(lambda x:(x**3)%4,[1,7,8,12,14,21,22,63,60]))
print(k)
