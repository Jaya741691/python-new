# %%
a = float(input())
g = a*1000
print(a,"kg = ",g,"gram")

# %%
a = float(input())
b = (a*(9/5))+32
print(a,"C = ",b,"F")

# %%
a = int(input())
b = int(input())
c = int(input())

if (a>b) and (a>c):
    print(a,"is big")

if (b>c) and (b>c):
    print(b,"is big")

else:
    print(c,"is big")

# %%
a = int(input('1st : '))
b = int(input('2nd : '))
c = input('operation : ')

if (c=='+') :
    print(a+b)
elif (c=='*'):
    print(a*b)
elif (c=='*'):
    print(a*b)
elif (c=='/'):
    print(a/b)
elif (c=='//'):
    print(a//b)
elif (c=='**'):
    print(a**b)
else:
    print("operation is invalid")
# Out:
# 42

# %%
n=int(input())
for i in range(n+1):
    print('CVCOP')
# Out:
# CVCOP
# CVCOP
# CVCOP
# CVCOP
# CVCOP
# CVCOP
# CVCOP
# CVCOP
# CVCOP
# CVCOP
# CVCOP
# CVCOP
# CVCOP
# CVCOP

# %%
for i in range(250,551):
    if (i%11==0):
        print(i)
# Out:
# 253
# 264
# 275
# 286
# 297
# 308
# 319
# 330
# 341
# 352
# 363
# 374
# 385
# 396
# 407
# 418
# 429
# 440
# 451
# 462
# 473
# 484
# 495
# 506
# 517
# 528
# 539
# 550

# %%
s=0
for i in range(56,153):
    s+=i
print(s)
# Out:
# 10088

# %%
for i in range(700,901):
    if(i%2==0):
        print(i)
# Out:
# 700
# 702
# 704
# 706
# 708
# 710
# 712
# 714
# 716
# 718
# 720
# 722
# 724
# 726
# 728
# 730
# 732
# 734
# 736
# 738
# 740
# 742
# 744
# 746
# 748
# 750
# 752
# 754
# 756
# 758
# 760
# 762
# 764
# 766
# 768
# 770
# 772
# 774
# 776
# 778
# 780
# 782
# 784
# 786
# 788
# 790
# 792
# 794
# 796
# 798
# 800
# 802
# 804
# 806
# 808
# 810
# 812
# 814
# 816
# 818
# 820
# 822
# 824
# 826
# 828
# 830
# 832
# 834
# 836
# 838
# 840
# 842
# 844
# 846
# 848
# 850
# 852
# 854
# 856
# 858
# 860
# 862
# 864
# 866
# 868
# 870
# 872
# 874
# 876
# 878
# 880
# 882
# 884
# 886
# 888
# 890
# 892
# 894
# 896
# 898
# 900
